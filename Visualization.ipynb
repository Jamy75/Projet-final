# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('newdemography.csv')
df
# Out:
#        unique_id  Year Country / territory of asylum/residence  \
# 0              0  2001                             Afghanistan
# 1              1  2001                             Afghanistan
# 2              2  2001                             Afghanistan
# 3              3  2001                                  Angola
# 4              4  2001                                  Angola
# ...          ...   ...                                     ...
# 18351      18351  2016                                  Zambia
# 18352      18352  2016                                  Zambia
# 18353      18353  2016                                  Zambia
# 18354      18354  2016                                Zimbabwe
# 18355      18355  2016                                Zimbabwe
#
#                                        Location Name  Female 0-4  Female 5-17  \
# 0                                              Kabul           0            1
# ...

# %%
sns.set_style("darkgrid")

# %%
# Example plot using the "whitegrid" style
sns.scatterplot(data=df, x="Year", y="Female 0-4")
plt.title("Count baby female per year")
plt.show()

# %% [markdown]
# ## Count baby male

# %%
sns.set_style("whitegrid")
sns.scatterplot(data=df, x="Year", y="Male 0-4")
plt.title("Count baby female per year")
plt.show()

# %% [markdown]
# ### Count Underage female per year

# %%
sns.scatterplot(data=df, x="Year", y="Female 5-17")
plt.title("Count underage female per year")
plt.show()

# %% [markdown]
# ## Count underage male per year

# %%
sns.scatterplot(data=df, x="Year", y="Male 5-17")
plt.title("Count underage male per year")
plt.show()
